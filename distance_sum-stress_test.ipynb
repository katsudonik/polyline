# %%
import numpy as np
from numpy.random import *
import math

# %%
count = 3600 * 12

# %%
_lo = np.array(rand(count))

# %%
_la = _lo**3

# %%
lo = np.sort(_lo + 35) 
la = np.sort(_la + 139)
points_d = np.c_[lo, la]

# %%
points_d
# Out:
# array([[ 35.00000577, 139.        ],
#        [ 35.00000801, 139.        ],
#        [ 35.00004782, 139.        ],
#        ...,
#        [ 35.99984439, 139.99953324],
#        [ 35.99988422, 139.9996527 ],
#        [ 35.99993962, 139.99981887]])

# %%
_points = points_d
points = points_d

# %%
points = np.delete(points, -1 , 0)

# %%
points
# Out:
# array([[ 35.00000577, 139.        ],
#        [ 35.00000801, 139.        ],
#        [ 35.00004782, 139.        ],
#        ...,
#        [ 35.99981724, 139.99945183],
#        [ 35.99984439, 139.99953324],
#        [ 35.99988422, 139.9996527 ]])

# %%
_points = np.delete(_points, 0 , 0)

# %%
_points
# Out:
# array([[ 35.00000801, 139.        ],
#        [ 35.00004782, 139.        ],
#        [ 35.00005841, 139.        ],
#        ...,
#        [ 35.99984439, 139.99953324],
#        [ 35.99988422, 139.9996527 ],
#        [ 35.99993962, 139.99981887]])

# %%
v = np.c_[points, _points]

# %%
v
# Out:
# array([[ 35.00000577, 139.        ,  35.00000801, 139.        ],
#        [ 35.00000801, 139.        ,  35.00004782, 139.        ],
#        [ 35.00004782, 139.        ,  35.00005841, 139.        ],
#        ...,
#        [ 35.99981724, 139.99945183,  35.99984439, 139.99953324],
#        [ 35.99984439, 139.99953324,  35.99988422, 139.9996527 ],
#        [ 35.99988422, 139.9996527 ,  35.99993962, 139.99981887]])

# %%
b1 = np.array(["outputType", "ellipsoid", "latitude1", "longitude1", "latitude2", "longitude2"])

# %%
b1
# Out:
# array(['outputType', 'ellipsoid', 'latitude1', 'longitude1', 'latitude2',
#        'longitude2'], dtype='<U10')

# %%
import requests
import json

DISTANCE_API = "http://vldb.gsi.go.jp/sokuchi/surveycalc/surveycalc/bl2st_calc.pl"

# %%
def distance(payload):
    r = requests.get(DISTANCE_API, params=payload).json()
    return r['OutputData']['geoLength']

# %%
_d = 0
for point in v:
    point = np.r_[["json", "bessel"], point]
    _v = np.vstack((b1, point))
    _v = _v.transpose()
    _v = dict(_v)
    print(_v)
    d = distance(_v)
    print(d)
    _d = _d + float(d)
# Out:
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.00014737562787', 'longitude1': '139.00025634071227', 'latitude2': '35.00027018386516', 'longitude2': '139.00037457491968'}
# 17.380
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.00027018386516', 'longitude1': '139.00037457491968', 'latitude2': '35.0002719529474', 'longitude2': '139.00056925910528'}
# 17.771
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.0002719529474', 'longitude1': '139.00056925910528', 'latitude2': '35.000312262043224', 'longitude2': '139.00065491575123'}
# 9.007
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.000312262043224', 'longitude1': '139.00065491575123', 'latitude2': '35.00090981782909', 'longitude2': '139.0006793367047'}
# 66.324
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.00090981782909', 'longitude1': '139.0006793367047', 'latitude2': '35.00105578370231', 'longitude2': '139.00081363514062'}
# 20.309
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.00105578370231', 'longitude1': '139.00081363514062', 'latitude2': '35.001066101340626', 'longitude2': '139.00087142260955'}
# 5.397
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.001066101340626', 'longitude1': '139.00087142260955', 'latitude2': '35.001258030085594', 'longitude2': '139.00113678853123'}
# 32.249
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.001258030085594', 'longitude1': '139.00113678853123', 'latitude2': '35.001442987552004', 'longitude2': '139.0025057533335'}
# 126.626
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.001442987552004', 'longitude1': '139.0025057533335', 'latitude2': '35.002659778537414', 'longitude2': '139.00260172052103'}
# 135.261
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.002659778537414', 'longitude1': '139.00260172052103', 'latitude2': '35.003224969261055', 'longitude2': '139.00293420319488'}
# 69.654
# {'outputType': 'json', 'ellipsoid': 'bessel', 'latitude1': '35.003224969261055', 'longitude1': '139.00293420319488', 'latitude2': '35.004968786495866', 'longitude2': '139.00319114037188'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-96-84bbcb55ce9b> in <module>()
#       6     _v = dict(_v)
#       7     print(_v)
# ----> 8     d = distance(_v)
#       9     print(d)
#      10     _d = _d + float(d)
#
# <ipython-input-95-89cb5bd4129e> in distance(payload)
#       1 def distance(payload):
# ----> 2     r = requests.get(DISTANCE_API, params=payload).json()
#       3     return r['OutputData']['geoLength']
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     628
#     629         # Resolve redirects if allowed.
# --> 630         history = [resp for resp in gen] if allow_redirects else []
#     631
#     632         # Shuffle things around if there's history.
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/sessions.py in <listcomp>(.0)
#     628
#     629         # Resolve redirects if allowed.
# --> 630         history = [resp for resp in gen] if allow_redirects else []
#     631
#     632         # Shuffle things around if there's history.
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, **adapter_kwargs)
#     188                 proxies=proxies,
#     189                 allow_redirects=False,
# --> 190                 **adapter_kwargs
#     191             )
#     192
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     592                                                   timeout=timeout_obj,
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#     596             # If we're going to release the connection in ``finally:``, then
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     348         # Trigger any extra validation we need to do.
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#     352             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     833         # Force connect early to allow us to validate the connection.
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#     837         if not conn.is_verified:
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     321             ca_cert_dir=self.ca_cert_dir,
#     322             server_hostname=hostname,
# --> 323             ssl_context=context)
#     324
#     325         if self.assert_fingerprint:
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     322         context.load_cert_chain(certfile, keyfile)
#     323     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 324         return context.wrap_socket(sock, server_hostname=server_hostname)
#     325
#     326     warnings.warn(
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     415         while True:
#     416             try:
# --> 417                 cnx.do_handshake()
#     418             except OpenSSL.SSL.WantReadError:
#     419                 rd, _, _ = select.select([sock], [], [], sock.gettimeout())
#
# /root/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1423         :return: None.
#    1424         """
# -> 1425         result = _lib.SSL_do_handshake(self._ssl)
#    1426         self._raise_ssl_error(self._ssl, result)
#    1427
#
# KeyboardInterrupt:

# %%
_d
# Out:
# 499.97799999999995

# %%
import folium
import numpy as np
import math

points = np.array(points_d)
location = [( np.max(points[:,0]) + np.min(points[:,0]) ) / 2, ( np.max(points[:,1]) + np.min(points[:,1]) ) / 2]

width = np.max([( np.max(points[:,0]) - np.min(points[:,0]) ),  ( np.max(points[:,1]) - np.min(points[:,1]) )])

points = points.tolist()

x = width

zoom = math.log(5*x/9500, 0.5)

m = folium.Map(location=location, zoom_start=zoom)
folium.PolyLine(points).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
